# %%
coins=[1, 5, 10, 20]
Amount = 37
while Amount>0:
        j=len(coins)-1
        counter=0
        print(counter)
        if Amount<=coins[j]:
                counter=counter+1
                Amount=Amount-coins[j]
        if j==0:
                print("hit")
